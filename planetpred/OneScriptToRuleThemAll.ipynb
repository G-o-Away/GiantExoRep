# %%
import sys
import os
#sys.path.append(os.path.dirname(os.path.realpath("__file__")))
print(os.path.realpath("__file__"))
print(os.path.dirname(os.path.realpath("__file__")))
print(sys.path.append('os.path.dirname(os.path.realpath("__file__"))'))

# stuff that works better for ipynb
sys.path.append("../")
# Out:
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\__file__
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred
# None

# %%
from planetpred.simulation_final_nrh import set_parameters
from planetpred.simulation_plots import plot_parameters
from planetpred.simulation_hyp_plots import hyp_plot_parameters

# %% [markdown]
# <br>
# Description of keywords:<br>
# setname = Which folder and yaml file are being run on<br>
# goldenYN = Whether to separate a golden set to be tested on<br>
# XFeYN = Whether to plot [X/Fe] (True) or [X/H] (False)<br>
# plotYN = Whether to save plots (True) or not (False)<br>
# input_file_name = File that has abundances and whether a star is an exoplanet host star<br>

# %% [markdown]
# file_name = "simulation_final_nrh.py"

# %%
setname = "set1"
goldenYN = "True"
XFeYN = "True"
plotYN = "True"
input_file_name = "combined-dataset_matched.csv"

# %%
for i in range(25):
    set_parameters(set_name=setname, golden_set=goldenYN, input_file=input_file_name)
    plot_parameters(set_name=setname)
    hyp_plot_parameters(set_name=setname, plotXFe=XFeYN, saveplot=plotYN)
# Out:
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 83
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 38
# 2 	 	 239
# 3 	 	 70
# 4 	 	 32
# 5 	 	 33
# 6 	 	 35
# 7 	 	 61
# 8 	 	 3
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 9 	 	 47
# [[0.981 0.019]
#  [0.033 0.967]]
# Number of most probable planet hosts: 202
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [216, 1203, 2014, 2263, 3074, 3379, 4070, 6131, 6263, 6617]
# [np.int64(3869), np.int64(21109), np.int64(38041), np.int64(43297), np.int64(59610), np.int64(65407), np.int64(77655), np.int64(107251), np.int64(109577), np.int64(115662)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2038.pdf
# [[0.981 0.019]
#  [0.033 0.967]]
#
# C     1.000000
# O     0.908060
# Na    0.617914
# Mg    0.593535
# Al    0.657717
# Si    0.785900
# Ca    0.628418
# Sc    0.701472
# Ti    0.764158
# V     0.800624
# Mn    0.814191
# Y1    0.566319
# Cr    0.826230
# Co    0.559964
# Ni    0.462736
# Fe    0.893913
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 70
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 92
# 2 	 	 17
# 3 	 	 54
# 4 	 	 74
# 5 	 	 40
# 6 	 	 18
# 7 	 	 101
# 8 	 	 30
# 9 	 	 15
# [[0.981 0.019]
#  [0.026 0.974]]
# Number of most probable planet hosts: 244
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [216, 388, 1281, 1305, 1696, 4070, 4527, 4863, 5054, 6247]
# [np.int64(3869), np.int64(6993), np.int64(22336), np.int64(22627), np.int64(30579), np.int64(77655), np.int64(83983), np.int64(88595), np.int64(90988), np.int64(109388)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2038.pdf
# [[0.981 0.019]
#  [0.026 0.974]]
#
# C     0.960287
# O     1.000000
# Na    0.737039
# Mg    0.697498
# Al    0.586876
# Si    0.573879
# Ca    0.627157
# Sc    0.731360
# Ti    0.906982
# V     0.780590
# Mn    0.809589
# Y1    0.566124
# Cr    0.900738
# Co    0.589544
# Ni    0.411702
# Fe    0.840681
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 65
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 50
# 2 	 	 45
# 3 	 	 91
# 4 	 	 34
# 5 	 	 48
# 6 	 	 21
# 7 	 	 33
# 8 	 	 57
# 9 	 	 156
# [[0.988 0.012]
#  [0.021 0.979]]
# Number of most probable planet hosts: 230
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [310, 1481, 2194, 4070, 4778, 4872, 5060, 5184, 5662, 6473]
# [np.int64(5763), np.int64(26394), np.int64(42098), np.int64(77655), np.int64(87330), np.int64(88650), np.int64(91085), np.int64(92895), np.int64(99306), np.int64(113421)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2038.pdf
# [[0.988 0.012]
#  [0.021 0.979]]
#
# C     1.000000
# O     0.951333
# Na    0.614576
# Mg    0.615860
# Al    0.536045
# Si    0.655343
# Ca    0.783024
# Sc    0.715296
# Ti    0.673720
# V     0.661724
# Mn    0.849429
# Y1    0.623919
# Cr    0.895132
# Co    0.555506
# Ni    0.560047
# Fe    0.842794
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 36
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 58
# 2 	 	 91
# 3 	 	 147
# 4 	 	 35
# 5 	 	 80
# 6 	 	 77
# 7 	 	 17
# 8 	 	 217
# 9 	 	 64
# [[0.992 0.008]
#  [0.013 0.987]]
# Number of most probable planet hosts: 271
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [922, 957, 2441, 2793, 2807, 3245, 3334, 6458, 6570, 6653]
# [np.int64(16537), np.int64(17096), np.int64(47087), np.int64(54232), np.int64(54413), np.int64(62653), np.int64(64457), np.int64(113137), np.int64(114840), np.int64(116250)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2039.pdf
# [[0.9915 0.0085]
#  [0.013  0.987 ]]
#
# C     1.000000
# O     0.991919
# Na    0.719349
# Mg    0.746164
# Al    0.606585
# Si    0.760586
# Ca    0.714572
# Sc    0.761695
# Ti    0.929348
# V     0.775820
# Mn    0.994054
# Y1    0.693353
# Cr    0.934994
# Co    0.599277
# Ni    0.487651
# Fe    0.906846
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 82
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 40
# 2 	 	 72
# 3 	 	 118
# 4 	 	 153
# 5 	 	 234
# 6 	 	 40
# 7 	 	 58
# 8 	 	 47
# 9 	 	 148
# [[0.994 0.006]
#  [0.008 0.992]]
# Number of most probable planet hosts: 223
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [90, 551, 596, 2691, 2962, 3206, 3502, 3516, 4430, 6473]
# [np.int64(1666), np.int64(9884), np.int64(10657), np.int64(52521), np.int64(57467), np.int64(62039), np.int64(67537), np.int64(67851), np.int64(82651), np.int64(113421)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2039.pdf
# [[0.994  0.006 ]
#  [0.0075 0.9925]]
#
# C     0.909947
# O     0.929345
# Na    0.636904
# Mg    0.691222
# Al    0.628657
# Si    0.676339
# Ca    0.568403
# Sc    0.681947
# Ti    0.763092
# V     0.712396
# Mn    1.000000
# Y1    0.692487
# Cr    0.851059
# Co    0.601661
# Ni    0.357736
# Fe    0.795727
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 36
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 105
# 2 	 	 48
# 3 	 	 104
# 4 	 	 58
# 5 	 	 54
# 6 	 	 227
# 7 	 	 76
# 8 	 	 148
# 9 	 	 31
# [[0.996 0.004]
#  [0.007 0.993]]
# Number of most probable planet hosts: 244
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [90, 344, 388, 551, 751, 3272, 3787, 4863, 5409, 6644]
# [np.int64(1666), np.int64(6390), np.int64(6993), np.int64(9884), np.int64(13467), np.int64(63203), np.int64(73136), np.int64(88595), np.int64(95740), np.int64(116084)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2039.pdf
# [[0.996  0.004 ]
#  [0.0065 0.9935]]
#
# C     0.908194
# O     1.000000
# Na    0.673011
# Mg    0.709551
# Al    0.682188
# Si    0.733841
# Ca    0.830453
# Sc    0.774706
# Ti    0.817853
# V     0.695806
# Mn    0.845965
# Y1    0.614163
# Cr    0.846378
# Co    0.557615
# Ni    0.485336
# Fe    0.851032
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 96
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 1
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 2 	 	 49
# 3 	 	 136
# 4 	 	 239
# 5 	 	 34
# 6 	 	 85
# 7 	 	 74
# 8 	 	 156
# 9 	 	 57
# [[0.982 0.018]
#  [0.028 0.972]]
# Number of most probable planet hosts: 225
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [688, 1023, 1710, 2189, 3015, 3297, 4744, 4778, 6067, 6082]
# [np.int64(12247), np.int64(18451), np.int64(30905), np.int64(41997), np.int64(58331), np.int64(63833), np.int64(86796), np.int64(87330), np.int64(106006), np.int64(106440)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2039.pdf
# [[0.9825 0.0175]
#  [0.0285 0.9715]]
#
# C     0.977565
# O     0.958984
# Na    0.623635
# Mg    0.693020
# Al    0.684475
# Si    0.813452
# Ca    0.652786
# Sc    0.818094
# Ti    0.861694
# V     0.694814
# Mn    0.906648
# Y1    0.643144
# Cr    0.833129
# Co    0.707291
# Ni    0.511820
# Fe    1.000000
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 41
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 48
# 2 	 	 87
# 3 	 	 71
# 4 	 	 114
# 5 	 	 71
# 6 	 	 87
# 7 	 	 30
# 8 	 	 60
# 9 	 	 25
# [[0.995 0.005]
#  [0.016 0.983]]
# Number of most probable planet hosts: 367
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [188, 553, 1252, 2290, 2493, 2507, 3003, 3787, 4673, 6300]
# [np.int64(3479), np.int64(9960), np.int64(21850), np.int64(43803), np.int64(48455), np.int64(48739), np.int64(58237), np.int64(73136), np.int64(85911), np.int64(110094)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2040.pdf
# [[0.995  0.005 ]
#  [0.0165 0.9835]]
#
# C     1.000000
# O     0.995437
# Na    0.730219
# Mg    0.761681
# Al    0.568714
# Si    0.696597
# Ca    0.723629
# Sc    0.857740
# Ti    0.887689
# V     0.689503
# Mn    0.969842
# Y1    0.770610
# Cr    0.950833
# Co    0.553553
# Ni    0.447808
# Fe    0.826571
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 50
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 9
# 2 	 	 32
# 3 	 	 138
# 4 	 	 44
# 5 	 	 200
# 6 	 	 58
# 7 	 	 202
# 8 	 	 45
# 9 	 	 65
# [[0.99  0.01 ]
#  [0.024 0.975]]
# Number of most probable planet hosts: 287
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [952, 1063, 2005, 3196, 3274, 3660, 3885, 3895, 4744, 4778]
# [np.int64(17054), np.int64(19207), np.int64(37826), np.int64(61740), np.int64(63242), np.int64(70695), np.int64(74793), np.int64(74890), np.int64(86796), np.int64(87330)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2040.pdf
# [[0.99   0.01  ]
#  [0.0245 0.9755]]
#
# C     1.000000
# O     0.868084
# Na    0.712188
# Mg    0.682937
# Al    0.700598
# Si    0.610099
# Ca    0.650143
# Sc    0.733598
# Ti    0.843922
# V     0.729709
# Mn    0.866050
# Y1    0.617023
# Cr    0.819598
# Co    0.607325
# Ni    0.515830
# Fe    0.885223
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 41
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 86
# 2 	 	 129
# 3 	 	 112
# 4 	 	 48
# 5 	 	 49
# 6 	 	 30
# 7 	 	 112
# 8 	 	 31
# 9 	 	 31
# [[0.988 0.012]
#  [0.018 0.982]]
# Number of most probable planet hosts: 285
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [626, 1491, 2200, 2483, 2611, 2749, 2848, 3076, 3695, 6244]
# [np.int64(11130), np.int64(26638), np.int64(42202), np.int64(48235), np.int64(50887), np.int64(53545), np.int64(55409), np.int64(59625), np.int64(71395), np.int64(109378)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2040.pdf
# [[0.9885 0.0115]
#  [0.0175 0.9825]]
#
# C     0.906609
# O     1.000000
# Na    0.671552
# Mg    0.717820
# Al    0.605258
# Si    0.684769
# Ca    0.644939
# Sc    0.753572
# Ti    0.815363
# V     0.706005
# Mn    0.922509
# Y1    0.601614
# Cr    0.787877
# Co    0.615483
# Ni    0.476103
# Fe    0.938045
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 76
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 17
# 2 	 	 65
# 3 	 	 75
# 4 	 	 54
# 5 	 	 168
# 6 	 	 7
# 7 	 	 43
# 8 	 	 61
# 9 	 	 104
# [[0.983 0.016]
#  [0.02  0.98 ]]
# Number of most probable planet hosts: 235
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [922, 1481, 1778, 3272, 3660, 3869, 4872, 5054, 5512, 5560]
# [np.int64(16537), np.int64(26394), np.int64(32916), np.int64(63203), np.int64(70695), np.int64(74500), np.int64(88650), np.int64(90988), np.int64(97233), np.int64(97938)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2040.pdf
# [[0.9835 0.0165]
#  [0.0205 0.9795]]
#
# C     0.899792
# O     1.000000
# Na    0.687998
# Mg    0.656147
# Al    0.651164
# Si    0.625529
# Ca    0.599304
# Sc    0.725178
# Ti    0.781909
# V     0.731739
# Mn    0.837824
# Y1    0.670071
# Cr    0.846101
# Co    0.602431
# Ni    0.501216
# Fe    0.906901
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 161
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 35
# 2 	 	 26
# 3 	 	 40
# 4 	 	 106
# 5 	 	 245
# 6 	 	 73
# 7 	 	 99
# 8 	 	 101
# 9 	 	 65
# [[0.994 0.006]
#  [0.01  0.99 ]]
# Number of most probable planet hosts: 244
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [1389, 1865, 2276, 2445, 3404, 3927, 4778, 4872, 4984, 5537]
# [np.int64(24275), np.int64(34693), np.int64(43569), np.int64(47193), np.int64(65808), np.int64(75281), np.int64(87330), np.int64(88650), np.int64(90004), np.int64(97546)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2041.pdf
# [[0.994 0.006]
#  [0.01  0.99 ]]
#
# C     1.000000
# O     0.989116
# Na    0.654013
# Mg    0.773165
# Al    0.688683
# Si    0.686972
# Ca    0.709231
# Sc    0.770539
# Ti    0.796756
# V     0.752047
# Mn    0.852237
# Y1    0.656346
# Cr    0.896038
# Co    0.658636
# Ni    0.510980
# Fe    0.892410
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 140
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 56
# 2 	 	 178
# 3 	 	 99
# 4 	 	 121
# 5 	 	 45
# 6 	 	 100
# 7 	 	 82
# 8 	 	 102
# 9 	 	 9
# [[0.993 0.007]
#  [0.014 0.986]]
# Number of most probable planet hosts: 241
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [90, 288, 998, 3288, 4043, 4174, 4633, 4850, 5054, 5924]
# [np.int64(1666), np.int64(5301), np.int64(17960), np.int64(63584), np.int64(77301), np.int64(79219), np.int64(85294), np.int64(88414), np.int64(90988), np.int64(103768)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2041.pdf
# [[0.993  0.007 ]
#  [0.0135 0.9865]]
#
# C     0.928143
# O     1.000000
# Na    0.631320
# Mg    0.630886
# Al    0.643110
# Si    0.570743
# Ca    0.577215
# Sc    0.703780
# Ti    0.755883
# V     0.655703
# Mn    0.825471
# Y1    0.701887
# Cr    0.833049
# Co    0.569547
# Ni    0.564475
# Fe    0.842414
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 98
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 45
# 2 	 	 28
# 3 	 	 31
# 4 	 	 40
# 5 	 	 34
# 6 	 	 28
# 7 	 	 5
# 8 	 	 77
# 9 	 	 78
# [[0.98  0.02 ]
#  [0.034 0.966]]
# Number of most probable planet hosts: 278
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [1025, 2005, 2856, 2962, 2977, 3314, 3363, 3907, 4850, 4984]
# [np.int64(18527), np.int64(37826), np.int64(55507), np.int64(57467), np.int64(57735), np.int64(64184), np.int64(65042), np.int64(75049), np.int64(88414), np.int64(90004)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2041.pdf
# [[0.9805 0.0195]
#  [0.034  0.966 ]]
#
# C     0.963345
# O     0.970331
# Na    0.665326
# Mg    0.557623
# Al    0.513770
# Si    0.737271
# Ca    0.620879
# Sc    0.676810
# Ti    0.701181
# V     0.661750
# Mn    0.965589
# Y1    0.615025
# Cr    0.826264
# Co    0.532110
# Ni    0.450848
# Fe    1.000000
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 44
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 71
# 2 	 	 63
# 3 	 	 278
# 4 	 	 119
# 5 	 	 38
# 6 	 	 84
# 7 	 	 63
# 8 	 	 133
# 9 	 	 50
# [[0.996 0.003]
#  [0.009 0.991]]
# Number of most probable planet hosts: 230
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [216, 344, 742, 998, 1169, 2807, 3038, 3938, 4174, 5021]
# [np.int64(3869), np.int64(6390), np.int64(13291), np.int64(17960), np.int64(20723), np.int64(54413), np.int64(58952), np.int64(75458), np.int64(79219), np.int64(90485)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2042.pdf
# [[0.9965 0.0035]
#  [0.009  0.991 ]]
#
# C     0.936088
# O     1.000000
# Na    0.649621
# Mg    0.667749
# Al    0.569566
# Si    0.643094
# Ca    0.574065
# Sc    0.724134
# Ti    0.769859
# V     0.700253
# Mn    0.844020
# Y1    0.655075
# Cr    0.847582
# Co    0.559278
# Ni    0.464352
# Fe    0.882780
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 120
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 111
# 2 	 	 109
# 3 	 	 35
# 4 	 	 60
# 5 	 	 13
# 6 	 	 104
# 7 	 	 35
# 8 	 	 61
# 9 	 	 206
# [[0.992 0.008]
#  [0.012 0.988]]
# Number of most probable planet hosts: 223
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [1734, 2263, 2815, 2903, 3885, 3900, 4474, 4701, 5409, 6124]
# [np.int64(31674), np.int64(43297), np.int64(54597), np.int64(56572), np.int64(74793), np.int64(74948), np.int64(83289), np.int64(86221), np.int64(95740), np.int64(107160)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2042.pdf
# [[0.9925 0.0075]
#  [0.0125 0.9875]]
#
# C     0.933692
# O     1.000000
# Na    0.656118
# Mg    0.749042
# Al    0.640633
# Si    0.700527
# Ca    0.644657
# Sc    0.761189
# Ti    0.871309
# V     0.704822
# Mn    0.888323
# Y1    0.741928
# Cr    0.848823
# Co    0.589203
# Ni    0.535267
# Fe    0.769853
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 74
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 42
# 2 	 	 39
# 3 	 	 97
# 4 	 	 19
# 5 	 	 99
# 6 	 	 52
# 7 	 	 111
# 8 	 	 70
# 9 	 	 99
# [[0.993 0.007]
#  [0.014 0.986]]
# Number of most probable planet hosts: 240
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [742, 952, 1183, 1636, 2905, 3015, 3869, 5366, 5649, 6352]
# [np.int64(13291), np.int64(17054), np.int64(20889), np.int64(29550), np.int64(56640), np.int64(58331), np.int64(74500), np.int64(95124), np.int64(99115), np.int64(111136)]
# ...
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 45
# 2 	 	 33
# 3 	 	 47
# 4 	 	 32
# 5 	 	 56
# 6 	 	 8
# 7 	 	 48
# 8 	 	 46
# 9 	 	 59
# [[0.987 0.013]
#  [0.02  0.98 ]]
# Number of most probable planet hosts: 296
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [85, 300, 2815, 3409, 4303, 4542, 4673, 4969, 5999, 6058]
# [np.int64(1547), np.int64(5529), np.int64(54597), np.int64(65891), np.int64(80838), np.int64(84171), np.int64(85911), np.int64(89844), np.int64(104780), np.int64(105854)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2043.pdf
# [[0.987 0.013]
#  [0.02  0.98 ]]
#
# C     0.900314
# O     1.000000
# Na    0.629688
# Mg    0.599842
# Al    0.588940
# Si    0.597535
# Ca    0.561417
# Sc    0.665687
# Ti    0.776295
# V     0.680365
# Mn    0.811872
# Y1    0.537586
# Cr    0.880005
# Co    0.506121
# Ni    0.431283
# Fe    0.936214
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 54
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 51
# 2 	 	 53
# 3 	 	 126
# 4 	 	 22
# 5 	 	 20
# 6 	 	 126
# 7 	 	 20
# 8 	 	 115
# 9 	 	 28
# [[0.98  0.02 ]
#  [0.025 0.975]]
# Number of most probable planet hosts: 262
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [47, 957, 1819, 2791, 2814, 3129, 3168, 4191, 5560, 6446]
# [np.int64(801), np.int64(17096), np.int64(33719), np.int64(54203), np.int64(54595), np.int64(60644), np.int64(61298), np.int64(79431), np.int64(97938), np.int64(113020)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2043.pdf
# [[0.9795 0.0205]
#  [0.025  0.975 ]]
#
# C     0.958606
# O     1.000000
# Na    0.678425
# Mg    0.673265
# Al    0.729938
# Si    0.644452
# Ca    0.773047
# Sc    0.735970
# Ti    0.807083
# V     0.634193
# Mn    0.882568
# Y1    0.605164
# Cr    0.779884
# Co    0.607418
# Ni    0.464253
# Fe    0.958658
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 68
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 98
# 2 	 	 67
# 3 	 	 183
# 4 	 	 80
# 5 	 	 48
# 6 	 	 48
# 7 	 	 53
# 8 	 	 178
# 9 	 	 45
# [[0.997 0.003]
#  [0.008 0.992]]
# Number of most probable planet hosts: 254
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [85, 190, 295, 300, 2791, 2959, 3379, 3901, 4872, 6617]
# [np.int64(1547), np.int64(3502), np.int64(5447), np.int64(5529), np.int64(54203), np.int64(57428), np.int64(65407), np.int64(74961), np.int64(88650), np.int64(115662)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2043.pdf
# [[0.997  0.003 ]
#  [0.0085 0.9915]]
#
# C     1.000000
# O     0.949367
# Na    0.713996
# Mg    0.692541
# Al    0.612611
# Si    0.734491
# Ca    0.674263
# Sc    0.713994
# Ti    0.795362
# V     0.718300
# Mn    0.980646
# Y1    0.640316
# Cr    0.862410
# Co    0.608246
# Ni    0.483246
# Fe    0.855849
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 96
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 95
# 2 	 	 93
# 3 	 	 108
# 4 	 	 10
# 5 	 	 70
# 6 	 	 31
# 7 	 	 145
# 8 	 	 39
# 9 	 	 38
# [[0.992 0.008]
#  [0.024 0.975]]
# Number of most probable planet hosts: 202
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [459, 1481, 2597, 2977, 3020, 3142, 3196, 4284, 5221, 5488]
# [np.int64(8159), np.int64(26394), np.int64(50653), np.int64(57735), np.int64(58451), np.int64(61020), np.int64(61740), np.int64(80680), np.int64(93281), np.int64(96861)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2044.pdf
# [[0.9925 0.0075]
#  [0.0245 0.9755]]
#
# C     0.956240
# O     1.000000
# Na    0.755539
# Mg    0.682221
# Al    0.645897
# Si    0.726009
# Ca    0.611506
# Sc    0.707497
# Ti    0.772070
# V     0.672016
# Mn    0.848730
# Y1    0.654995
# Cr    0.826699
# Co    0.587822
# Ni    0.454015
# Fe    0.881416
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 88
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 95
# 2 	 	 110
# 3 	 	 74
# 4 	 	 32
# 5 	 	 24
# 6 	 	 13
# 7 	 	 48
# 8 	 	 36
# 9 	 	 86
# [[0.98  0.02 ]
#  [0.022 0.978]]
# Number of most probable planet hosts: 267
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [271, 492, 2407, 2584, 3196, 3334, 3699, 4474, 5054, 5976]
# [np.int64(5054), np.int64(8770), np.int64(46471), np.int64(50473), np.int64(61740), np.int64(64457), np.int64(71481), np.int64(83289), np.int64(90988), np.int64(104436)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2044.pdf
# [[0.98  0.02 ]
#  [0.022 0.978]]
#
# C     1.000000
# O     0.983189
# Na    0.636343
# Mg    0.660417
# Al    0.578817
# Si    0.736401
# Ca    0.723943
# Sc    0.810532
# Ti    0.767024
# V     0.699906
# Mn    0.931852
# Y1    0.595674
# Cr    0.825985
# Co    0.580846
# Ni    0.503547
# Fe    0.884061
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0
# C:\Users\Yilin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\dtypes\common.py:1645: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   npdtype = np.dtype(dtype)
# Parameters used in simulation:
# ------------------------------
#
# cv_folds = 5
# early_stopping_rounds = 50
# N_iterations = 10
# N_samples = 200
# gas_giant_mass = 0.0945
# features = ['C', 'O', 'Na', 'Mg', 'Al', 'Si', 'Ca', 'Sc', 'Ti', 'V', 'Mn', 'Y1', 'Cr', 'Co', 'Ni', 'Fe']
# dropnans = False
# Number of samples used in simulation: 6768
#
# iteration 	 estimators
# ---------------------------
# 0 	 	 26
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\..\planetpred\simulation_final_nrh.py:186: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   feat_imp_train = pd.concat([feat_imp_train, pd.DataFrame(feat_imp, columns=features, index=[iteration])])
# 1 	 	 48
# 2 	 	 31
# 3 	 	 32
# 4 	 	 22
# 5 	 	 71
# 6 	 	 45
# 7 	 	 22
# 8 	 	 48
# 9 	 	 154
# [[0.985 0.015]
#  [0.026 0.974]]
# Number of most probable planet hosts: 271
# Saving data files
# Simulation completed successfully.
# Changed indices and HIP numbers:
# [252, 596, 1305, 1951, 2005, 2276, 2815, 3274, 3357, 4120]
# [np.int64(4715), np.int64(10657), np.int64(22627), np.int64(36795), np.int64(37826), np.int64(43569), np.int64(54597), np.int64(63242), np.int64(64797), np.int64(78521)]
# D:\OneDrive\GradClasses\Astro278\GiantExoRep\planetpred\set1\figures\Feature_importance-Oct27-2044.pdf
# [[0.985 0.015]
#  [0.026 0.974]]
#
# C     0.973237
# O     1.000000
# Na    0.717886
# Mg    0.674714
# Al    0.601843
# Si    0.606251
# Ca    0.713929
# Sc    0.670888
# Ti    0.734805
# V     0.674642
# Mn    0.898851
# Y1    0.668460
# Cr    0.878757
# Co    0.654746
# Ni    0.422202
# Fe    0.930515
# dtype: float64
# Na
# raw kstest nan
# cleankstest 0.0005094488060973505
# Mg
# raw kstest nan
# cleankstest 0.013646445011483236
# Al
# raw kstest nan
# cleankstest 0.01711339632997116
# Si
# raw kstest nan
# cleankstest 0.03408974322252415
# Ca
# raw kstest nan
# cleankstest 0.14770264562682744
# Sc
# raw kstest nan
# cleankstest 0.051131516310382034
# Ti
# raw kstest nan
# cleankstest 0.006523288012920688
# V
# raw kstest nan
# cleankstest 0.00452340856150053
# Cr
# raw kstest nan
# cleankstest 2.2868633431625954e-05
# Mn
# raw kstest nan
# cleankstest 0.10897344461198216
# Co
# raw kstest nan
# cleankstest 0.000433606579379807
# Ni
# raw kstest nan
# cleankstest 0.0017400136907788778
# Y1
# raw kstest nan
# cleankstest 0.8183022943418913
# C
# raw kstest nan
# cleankstest 0.0012895588069175717
# O
# raw kstest nan
# cleankstest 0.8343891077805182
# Fe
# raw kstest 1.0
# cleankstest 1.0

# %%
print("Save the last planet_probabilities lists as _big and run simulation_hyp_plots")
# Out:
# Save the last planet_probabilities lists as _big and run simulation_hyp_plots
